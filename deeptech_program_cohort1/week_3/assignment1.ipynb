# %%
import torch

def f(x):
    return x**4 + 4*x**3 + 10*x**2 + 3*x + 11

x = torch.tensor([3.0], requires_grad=True)

grad_f = torch.autograd.grad(f(x), x)[0]

print(grad_f)
# Out:
# tensor([279.])
