# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red","Yellow", "White"])
colours
# Out:
# 0       Red
# 1    Yellow
# 2     White
# dtype: object

# %%
# DataFrame = 2-dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make  Colour
# 0      BMW     Red
# 1   Toyota  Yellow
# 2    Honda   White

# %%
 # Import data
car_sales = pd.read_csv("../car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting data
car_sales.to_csv("exported-car-sales.csv", index=False)

# %% [raw]
# exported_sales = pd.read_csv("exported-car-sales.csv")
# exported_sales

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00 $5,000.00 $7,000.00 $22,000.00 $3,50...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
car_sales["Doors"].median()
# Out:
# 4.0

# %%
car_sales["Doors"].std()
# Out:
# 0.4714045207910317

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()  # converts the data in "Make" column to lowercase

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].replace('[$,]', '', regex=True).astype(float).astype(int)

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
# car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# Column from series
# series_column = pd.Series([5,5,5,5,5])

# New column called Seats
car_sales["Seats"] = pd.Series([5,5,5,5,5])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=False)
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: Seats, dtype: float64

# %%
# Column from Python list
fuel_economy = [4.5, 5.6, 4.6, 2.7, 8.7, 6.5, 7.6, 5.3, 8.9, 9.3]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3

# %%
car_sales["Age of Car"] = pd.Series([12, 8, 4, 9, 5])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car
# 0        12.0
# 1         8.0
# 2         4.0
# 3         9.0
# 4         5.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
driver_age = [32, 34, 33, 23, 19, 17, 20, 22, 21, 60]
car_sales["Driver's Age"] = driver_age

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age
# 0        12.0            32
# 1         8.0            34
# 2         4.0            33
# 3         9.0            23
# 4         5.0            19
# 5         NaN            17
# 6         NaN            20
# 7         NaN            22
# 8         NaN            21
# 9         NaN            60

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)
# 0        12.0            32             6751.935
# 1         8.0            34             4922.344
# 2         4.0            33             1497.254
# 3         9.0            23              301.833
# 4         5.0            19            18539.265
# 5         NaN            17             6448.845
# 6         NaN            20             3473.048
# 7         NaN            22             2901.114
# 8         NaN            21             5340.000
# 9         NaN            60             2938.800

# %%
# Creaate a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels
# 0        12.0            32             6751.935                 4
# 1         8.0            34             4922.344                 4
# 2         4.0            33             1497.254                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 7         NaN            22             2901.114                 4
# 8         NaN            21             5340.000                 4
# 9         NaN            60             2938.800                 4

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 1         8.0            34             4922.344                 4
# 2         4.0            33             1497.254                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 7         NaN            22             2901.114                 4
# 8         NaN            21             5340.000                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 1   honda    Red          87899      4   5000    5.0             5.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 9  nissan  White          31600      4   9700    NaN             9.3
# 0  toyota  White         150043      4   4000    5.0             4.5
# 8  toyota  White          60000      4   6250    NaN             8.9
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 5         NaN            17             6448.845                 4
# 7         NaN            22             2901.114                 4
# 2         4.0            33             1497.254                 4
# 1         8.0            34             4922.344                 4
# 3         9.0            23              301.833                 4
# 6         NaN            20             3473.048                 4
# 4         5.0            19            18539.265                 4
# 9         NaN            60             2938.800                 4
# 0        12.0            32             6751.935                 4
# 8         NaN            21             5340.000                 4
#
#    Passed road safety
# 5                True
# 7                True
# 2                True
# 1                True
# 3                True
# 6                True
# 4                True
# 9                True
# 0                True
# 8                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 8  toyota  White          60000      4   6250    NaN             8.9
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 1   honda    Red          87899      4   5000    5.0             5.6
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 2         4.0            33             1497.254                 4
# 8         NaN            21             5340.000                 4
# 7         NaN            22             2901.114                 4
# 1         8.0            34             4922.344                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 3                True
# 4                True
# 5                True
# 6                True
# 2                True
# 8                True
# 7                True
# 1                True
# 9                True

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#     Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 7  honda   Blue          54738      4   7000    NaN             5.3
# 3    bmw  Black          11179      5  22000    5.0             2.7
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 7         NaN            22             2901.114                 4
# 3         9.0            23              301.833                 4
#
#    Passed road safety
# 7                True
# 3                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 8  toyota  White          60000      4   6250    NaN             8.9
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 1   honda    Red          87899      4   5000    5.0             5.6
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 2         4.0            33             1497.254                 4
# 8         NaN            21             5340.000                 4
# 7         NaN            22             2901.114                 4
# 1         8.0            34             4922.344                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 3                True
# 4                True
# 5                True
# 6                True
# 2                True
# 8                True
# 7                True
# 1                True
# 9                True

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      0  toyota  White         150043      4   4000    5.0             4.5
# 1      3     bmw  Black          11179      5  22000    5.0             2.7
# 2      4  nissan  White         213095      4   3500    5.0             8.7
# 3      5  toyota  Green          99213      4   4500    NaN             6.5
# 4      6   honda   Blue          45698      4   7500    NaN             7.6
# 5      2  toyota   Blue          32549      3   7000    5.0             4.6
# 6      8  toyota  White          60000      4   6250    NaN             8.9
# 7      7   honda   Blue          54738      4   7000    NaN             5.3
# 8      1   honda    Red          87899      4   5000    5.0             5.6
# 9      9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 1         9.0            23              301.833                 4
# 2         5.0            19            18539.265                 4
# 3         NaN            17             6448.845                 4
# 4         NaN            20             3473.048                 4
# 5         4.0            33             1497.254                 4
# 6         NaN            21             5340.000                 4
# 7         NaN            22             2901.114                 4
# 8         8.0            34             4922.344                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1     bmw  Black          11179      5  22000    5.0             2.7
# 2  nissan  White         213095      4   3500    5.0             8.7
# 3  toyota  Green          99213      4   4500    NaN             6.5
# 4   honda   Blue          45698      4   7500    NaN             7.6
# 5  toyota   Blue          32549      3   7000    5.0             4.6
# 6  toyota  White          60000      4   6250    NaN             8.9
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8   honda    Red          87899      4   5000    5.0             5.6
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 1         9.0            23              301.833                 4
# 2         5.0            19            18539.265                 4
# 3         NaN            17             6448.845                 4
# 4         NaN            20             3473.048                 4
# 5         4.0            33             1497.254                 4
# 6         NaN            21             5340.000                 4
# 7         NaN            22             2901.114                 4
# 8         8.0            34             4922.344                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
car_sales.reset_index(drop=True, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 1         8.0            34             4922.344                 4
# 2         4.0            33             1497.254                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 7         NaN            22             2901.114                 4
# 8         NaN            21             5340.000                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
# Convert Odometer (KM) to miles
car_sales["Odometer (Mles)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             4.5
# 1   honda    Red          87899      4   5000    5.0             5.6
# 2  toyota   Blue          32549      3   7000    5.0             4.6
# 3     bmw  Black          11179      5  22000    5.0             2.7
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    NaN             6.5
# 6   honda   Blue          45698      4   7500    NaN             7.6
# 7   honda   Blue          54738      4   7000    NaN             5.3
# 8  toyota  White          60000      4   6250    NaN             8.9
# 9  nissan  White          31600      4   9700    NaN             9.3
#
#    Age of Car  Driver's Age  Total fuel used (L)  Number of wheels  \
# 0        12.0            32             6751.935                 4
# 1         8.0            34             4922.344                 4
# 2         4.0            33             1497.254                 4
# 3         9.0            23              301.833                 4
# 4         5.0            19            18539.265                 4
# 5         NaN            17             6448.845                 4
# 6         NaN            20             3473.048                 4
# 7         NaN            22             2901.114                 4
# 8         NaN            21             5340.000                 4
# 9         NaN            60             2938.800                 4
#
#    Passed road safety  Odometer (Mles)
# 0                True        93776.875
# 1                True        54936.875
# 2                True        20343.125
# 3                True         6986.875
# 4                True       133184.375
# 5                True        62008.125
# 6                True        28561.250
# 7                True        34211.250
# 8                True        37500.000
# 9                True        19750.000

# %%
car_sales = car_sales.drop(["Odometer (Mles)", "Odometer (Mis)"], axis=1)
car_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 car_sales = car_sales.drop(["Odometer (Mles)", "Odometer (Mis)"], axis=1)
#       2 car_sales
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Odometer (Mis)'] not found in axis"
